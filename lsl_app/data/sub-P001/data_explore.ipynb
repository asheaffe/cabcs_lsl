# %%
import pandas as pd 
import numpy as np 
import pyxdf
import os 
# os.getcwd()
data, info = pyxdf.load_xdf('PETER-TEST.xdf')
data
# Out:
# Stream 3: Calculated effective sampling rate 0.0000 Hz is different from specified rate 1.0000 Hz.
# Stream 8: Calculated effective sampling rate 0.0000 Hz is different from specified rate 0.2000 Hz.
# Stream 2: Calculated effective sampling rate 1.0011 Hz is different from specified rate 120.0000 Hz.
# Stream 10: Calculated effective sampling rate 0.0000 Hz is different from specified rate 25.0000 Hz.
# Stream 7: Calculated effective sampling rate 37.0691 Hz is different from specified rate 100.0000 Hz.
# [{'info': defaultdict(list,
#               {'name': ['HeartRate'],
#                'type': ['Biometrics'],
#                'channel_count': ['3'],
#                'channel_format': ['float32'],
#                'source_id': ['watch_HeartRate'],
#                'nominal_srate': ['1.000000000000000'],
#                'version': ['1.100000000000000'],
#                'created_at': ['817.8482582000000'],
#                'uid': ['1f3ec19e-f353-43d6-bd7f-a7cc5e7c2b85'],
# ...

# %%
fnirs = [x for x in data if 'OxySoft' in x['info']['name']][0]
fnirs
# Out:
# {'info': defaultdict(list,
#              {'name': ['OxySoft'],
#               'type': ['NIRS'],
#               'channel_count': ['28'],
#               'channel_format': ['float32'],
#               'source_id': ['OxySoft'],
#               'nominal_srate': ['75.00000000000000'],
#               'version': ['1.100000000000000'],
#               'created_at': ['878.0178039000000'],
#               'uid': ['9446482b-2b5b-446b-8634-5ff5ef0acb64'],
#               'session_id': ['default'],
#               'hostname': ['DESKTOP-JFELGPT'],
#               'v4address': [None],
#               'v4data_port': ['16576'],
#               'v4service_port': ['16579'],
#               'v6address': [None],
#               'v6data_port': ['16576'],
#               'v6service_port': ['16579'],
#               'desc': [defaultdict(list,
#                            {'manufacturer': ['Artinis Medical Systems B.V.'],
#                             'fiducials': [None],
# ...

# %%
fnirs['info'].keys()
# Out:
# dict_keys(['name', 'type', 'channel_count', 'channel_format', 'source_id', 'nominal_srate', 'version', 'created_at', 'uid', 'session_id', 'hostname', 'v4address', 'v4data_port', 'v4service_port', 'v6address', 'v6data_port', 'v6service_port', 'desc', 'stream_id', 'effective_srate', 'segments'])

# %%
fnirs['info']['desc']
# Out:
# [defaultdict(list,
#              {'manufacturer': ['Artinis Medical Systems B.V.'],
#               'fiducials': [None],
#               'channels': [defaultdict(list,
#                            {'channel': [defaultdict(list,
#                                          {'label': ['Rx1 - Tx1 O2Hb'],
#                                           'unit': ['umol'],
#                                           'type': ['NIRS'],
#                                           'location': [defaultdict(list,
#                                                        {'X': ['76.83'],
#                                                         'Y': ['79.2408'],
#                                                         'Z': ['54.3409']})]}),
#                              defaultdict(list,
#                                          {'label': ['Rx1 - Tx1 HHb'],
#                                           'unit': ['umol'],
#                                           'type': ['NIRS'],
# ...
